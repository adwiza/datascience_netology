# %%
import pandas as pd
import numpy as np
from collections import OrderedDict

# %%
# Проверяем версию Pandas
pd.__version__
# Out:
# '1.3.0'

# %% [markdown]
# ## Создание DataFrame из листов и словарей

# %%
datalist = [
    { 'date': '2017-07-01', 'value': 100 },
    { 'date': '2017-07-02', 'value': 200 },
    { 'date': '2017-07-03', 'value': 300 },
    { 'date': '2017-07-04', 'value': 400 },
    { 'date': '2017-07-05', 'value': 500 },
]

# %%
pd.DataFrame(datalist)
# Out:
#          date  value
# 0  2017-07-01    100
# 1  2017-07-02    200
# 2  2017-07-03    300
# 3  2017-07-04    400
# 4  2017-07-05    500

# %%
# тоже самое, но в другом виде
# задаём столбцы

datadict = { 
    'date': [ '2017-07-01', '2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05' ],
    'value': [ 100, 200, 300, 400, 500 ]
}

pd.DataFrame.from_dict(datadict)
# Out:
#          date  value
# 0  2017-07-01    100
# 1  2017-07-02    200
# 2  2017-07-03    300
# 3  2017-07-04    400
# 4  2017-07-05    500

# %%
# для сохранения порядка следования элементов можем использовать лист вместо словаря

datadict = [
    ('date', [ '2017-07-01', '2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05' ]),
    ('value', [ 100, 200, 300, 400, 500 ]),
]
pd.DataFrame.from_dict(OrderedDict(datadict))
# Out:
#          date  value
# 0  2017-07-01    100
# 1  2017-07-02    200
# 2  2017-07-03    300
# 3  2017-07-04    400
# 4  2017-07-05    500

# %%
# лист кортежей с указанием заголовков
datalists = [
    ('2017-07-01', 100),
    ('2017-07-02', 200),
    ('2017-07-03', 300),
    ('2017-07-04', 400),
    ('2017-07-05', 500),
]

headers = ['date', 'value']
pd.DataFrame.from_records(datalists, columns=headers)
# Out:
#          date  value
# 0  2017-07-01    100
# 1  2017-07-02    200
# 2  2017-07-03    300
# 3  2017-07-04    400
# 4  2017-07-05    500

# %% [markdown]
# ## Создание Series

# %%
# Можно использовать Numpy для генерации даннных
data_from_numpy = np.random.rand(3)

# %%
data_from_numpy
# Out:
# array([0.05613338, 0.12826815, 0.76148936])

# %%
pd.Series(data_from_numpy, index=['first', 'second', 'third'])
# Out:
# first     0.056133
# second    0.128268
# third     0.761489
# dtype: float64

# %% [markdown]
# ## Импорт данных для DataFrame из файлов

# %%
data = pd.read_csv('datasets/train.csv', delimiter=',')

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Столбцы SibSp и Parch (наличие рлодственников среди пассажиров) распознаны как целое число. Если надо это исправить
# то используем dtype

# %%
data = pd.read_csv('datasets/train.csv', delimiter=',', dtype={'SibSp':str, 'Parch': str})
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    object
#  7   Parch        891 non-null    object
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
# Статистика DataFrame
# Вывод зависит от типа данных
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age        Fare
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118   32.204208
# std     257.353842    0.486592    0.836071   14.526497   49.693429
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    7.910400
# 50%     446.000000    0.000000    3.000000   28.000000   14.454200
# 75%     668.500000    1.000000    3.000000   38.000000   31.000000
# max     891.000000    1.000000    3.000000   80.000000  512.329200

# %% [markdown]
# ## Распределения

# %%
type(data['Pclass'])
# Out:
# pandas.core.series.Series

# %%
data['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ## Гистограмма распределения

# %%
# рисуем в браузере
# %matplotlib inline

# %%
data.hist(column=['Age'])
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %% [markdown]
# Можно и так

# %%
data['Age'].hist(bins=25, figsize=(10, 5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Упражнение
#
# Загрузите в датафрейм mountains содержимое файла Mountains.csv. Посчитайте следующие показатели:
# 1. Минимальную и максимальную высоту гор в этом наборе
#
# 2. В каком году было впервые покорено наибольшее количество вершин (столбец First ascent)?
#
# 3. Постройте распределение распределение First ascent по годам

# %%
mountains = pd.read_csv('datasets/Homework/Mountains.csv')

# %%
mountains.head()
# Out:
#    Rank                                  Mountain  Height (m)  Height (ft)  \
# 0     1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1     2                K2 / Qogir / Godwin Austen        8611        28251
# 2     3                             Kangchenjunga        8586        28169
# 3     4                                    Lhotse        8516        27940
# 4     5                                    Makalu        8485        27838
#
#    Prominence (m)                   Range              Coordinates  \
# 0            8848     Mahalangur Himalaya  27°59′17″N 86°55′31″E﻿
# 1            4017       Baltoro Karakoram  35°52′53″N 76°30′48″E﻿
# 2            3922  Kangchenjunga Himalaya  27°42′12″N 88°08′51″E﻿
# 3             610     Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
# 4            2386     Mahalangur Himalaya  27°53′23″N 87°05′20″E﻿
#
#   Parent mountain First ascent Ascents bef. 2004  Failed attempts bef. 2004
# 0             NaN         1953            >>145                       121.0
# 1   Mount Everest         1954                45                       44.0
# 2   Mount Everest         1955                38                       24.0
# 3   Mount Everest         1956                26                       26.0
# 4   Mount Everest         1955                45                       52.0

# %%
mountains['Height (m)'].min()
# Out:
# 7200

# %%
mountains['Height (m)'].max()
# Out:
# 8848

# %%
mountains['First ascent'].value_counts().head(3)
# Out:
# 1960    7
# 1956    6
# 1976    6
# Name: First ascent, dtype: int64

# %%
mountains['First ascent'].hist(bins=25, figsize=(30, 15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Поэлементные действия с DataFrame

# %%
# Зададим 2 DataFrame

df1 = pd.DataFrame([(0, 1), (2, 3), (4, 5)], columns=['value1', 'value2'])
df1
# Out:
#    value1  value2
# 0       0       1
# 1       2       3
# 2       4       5

# %%
df2 = pd.DataFrame([(10, 11), (12, 13), (14, 15), (17, 18)], columns=['value1', 'value3'])
df2
# Out:
#    value1  value3
# 0      10      11
# 1      12      13
# 2      14      15
# 3      17      18

# %%
# Функция сложения
df1.add(df2)
# Out:
#    value1  value2  value3
# 0    10.0     NaN     NaN
# 1    14.0     NaN     NaN
# 2    18.0     NaN     NaN
# 3     NaN     NaN     NaN

# %%
# для несовпадающих строк используем значение из fill_value
df1.add(df2, fill_value=100).fillna(0)
# Out:
#    value1  value2  value3
# 0    10.0   101.0   111.0
# 1    14.0   103.0   113.0
# 2    18.0   105.0   115.0
# 3   117.0     0.0   118.0

# %% [markdown]
# ## mul - перемножение

# %%
df1.mul(df2, fill_value=0)
# Out:
#    value1  value2  value3
# 0     0.0     0.0     0.0
# 1    24.0     0.0     0.0
# 2    56.0     0.0     0.0
# 3     0.0     NaN     0.0

# %%
## div - поэлементное деление DataFrame
df1.div(df2, fill_value=17)
# Out:
#      value1    value2    value3
# 0  0.000000  0.058824  1.545455
# 1  0.166667  0.176471  1.307692
# 2  0.285714  0.294118  1.133333
# 3  1.000000       NaN  0.944444

# %% [markdown]
# ## Разность DataFrame

# %%
df1.sub(df2)
# Out:
#    value1  value2  value3
# 0   -10.0     NaN     NaN
# 1   -10.0     NaN     NaN
# 2   -10.0     NaN     NaN
# 3     NaN     NaN     NaN

# %% [markdown]
# ## Корректное копирование DataFrame

# %%
# зададим DataFrame

df1 = pd.DataFrame([(0, 1)], columns=['value1', 'value2'])
df1
# Out:
#    value1  value2
# 0       0       1

# %%
# Делаем его копию
df2 = df1

# %%
# изменяем значение в копии
df2['value1'][0] = 555

# %%
df2
# Out:
#    value1  value2
# 0     555       1

# %% [markdown]
# Смотрим, что произошло с исходным

# %%
df1
# Out:
#    value1  value2
# 0     555       1

# %% [markdown]
# Сделаем "настоящую" копию

# %%
df1 = pd.DataFrame([(0, 1)], columns=['value1', 'value2'])
df1
# Out:
#    value1  value2
# 0       0       1

# %%
df2 = df1.copy()

# %%
# изменяем значение в копии
df2['value1'][0] = 555

# %%
df2
# Out:
#    value1  value2
# 0     555       1

# %%
df1
# Out:
#    value1  value2
# 0       0       1

# %% [markdown]
# ## Сводные таблицы

# %%
data = pd.read_csv('datasets/train.csv', delimiter=',')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.pivot.html
# index - значения столбца, которые будут в строках
# columns - значения столбца, которые образуют столбцы
# values - значения в ячейках таблицы
# aggfunc - функция, которая будет применена к значениям

# среднее значение столбца 'Age' в разбивке по Sex и Embarked
pd.pivot_table(data, index=['Sex', 'Pclass'], columns=['Embarked'], values='Age', aggfunc=np.mean)
# Out:
# Embarked               C          Q          S
# Sex    Pclass
# female 1       36.052632  33.000000  32.704545
#        2       19.142857  30.000000  29.719697
#        3       14.062500  22.850000  23.223684
# male   1       40.111111  44.000000  41.897188
#        2       25.937500  57.000000  30.875889
#        3       25.016800  28.142857  26.574766

# %% [markdown]
# ### Apply - применить функцию к строке или столбцу

# %%
data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S
# 15      0            248706  16.0000   NaN        S
# 16      1            382652  29.1250   NaN        Q
# 17      0            244373  13.0000   NaN        S
# 18      0            345763  18.0000   NaN        S
# 19      0              2649   7.2250   NaN        C

# %%
def age_group(row):
    """
    Простая функция отнесения возраста к группе
    """
    
    # проверяем, что значение возраста не равно NaN
    if not pd.isnull(row['Age']):
        if row['Age'] <= 18:
            return 'Child'
        elif row['Age'] >= 65:
            return 'Ratiree'
        return 'Young'
    
    return 'Undef'

# %%
# применим функцию ageGroup к DataFrame и выведем результат в отдельный столбец ageGroup
data['ageGroup'] = data.apply(age_group, axis=1)

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked ageGroup
# 0      0         A/5 21171   7.2500   NaN        S    Young
# 1      0          PC 17599  71.2833   C85        C    Young
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Young
# 3      0            113803  53.1000  C123        S    Young
# 4      0            373450   8.0500   NaN        S    Young
# 5      0            330877   8.4583   NaN        Q    Undef
# 6      0             17463  51.8625   E46        S    Young
# 7      1            349909  21.0750   NaN        S    Child
# 8      2            347742  11.1333   NaN        S    Young
# 9      0            237736  30.0708   NaN        C    Child

# %% [markdown]
# ### Applymap - применяем функцию к каждой ячейке отдельно

# %%
# например, устанавливаем формат отображения

df = pd.DataFrame(np.random.randn(10, 3), columns=['first', 'second', 'third'])
df
# Out:
#       first    second     third
# 0  0.010100  0.132804 -0.867822
# 1 -0.609167  0.332750  0.077036
# 2 -0.779560 -0.138134 -0.042242
# 3 -1.125290  0.149144 -0.005692
# 4 -1.844688  1.248132 -0.921594
# 5 -0.610313 -2.906205  0.043159
# 6  2.418301 -0.439763 -0.327170
# 7 -0.326160 -0.932415  1.234899
# 8 -0.799114  0.893595 -1.410491
# 9 -0.278927 -1.400605 -0.159651

# %%
df.apply(lambda x: x ** 2)
# Out:
#       first    second     third
# 0  0.000102  0.017637  0.753116
# 1  0.371084  0.110723  0.005935
# 2  0.607714  0.019081  0.001784
# 3  1.266278  0.022244  0.000032
# 4  3.402874  1.557834  0.849335
# 5  0.372482  8.446030  0.001863
# 6  5.848178  0.193392  0.107040
# 7  0.106380  0.869398  1.524975
# 8  0.638584  0.798513  1.989484
# 9  0.077800  1.961694  0.025488

# %% [markdown]
# Классифицируйте высоту гор и посчитайте распределение количества вершин по этой классификации:
# * высота до 7500 метров - High
# * до 8000 метров - Very high
# * более 8000 метров - Extremely high

# %%
mountains.head()
# Out:
#    Rank                                  Mountain  Height (m)  Height (ft)  \
# 0     1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1     2                K2 / Qogir / Godwin Austen        8611        28251
# 2     3                             Kangchenjunga        8586        28169
# 3     4                                    Lhotse        8516        27940
# 4     5                                    Makalu        8485        27838
#
#    Prominence (m)                   Range              Coordinates  \
# 0            8848     Mahalangur Himalaya  27°59′17″N 86°55′31″E﻿
# 1            4017       Baltoro Karakoram  35°52′53″N 76°30′48″E﻿
# 2            3922  Kangchenjunga Himalaya  27°42′12″N 88°08′51″E﻿
# 3             610     Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
# 4            2386     Mahalangur Himalaya  27°53′23″N 87°05′20″E﻿
#
#   Parent mountain First ascent Ascents bef. 2004  Failed attempts bef. 2004
# 0             NaN         1953            >>145                       121.0
# 1   Mount Everest         1954                45                       44.0
# 2   Mount Everest         1955                38                       24.0
# 3   Mount Everest         1956                26                       26.0
# 4   Mount Everest         1955                45                       52.0

# %%
def mountain_height_group(row):
    """
    Простая функция отнесения высоты горы к группе
    """
    if not pd.isnull(row['Height (m)']):
        if row['Height (m)'] < 7500:
            return 'High'
        elif row['Height (m)'] > 7500 and row['Height (m)'] < 8000:
            return 'Very high'
        
        return 'Extremely high'

# %%
mountains['mountain_height_group'] = mountains.apply(mountain_height_group, axis=1)
mountains.tail(10)
mountains['mountain_height_group'].value_counts()
# Out:
# High              64
# Very high         40
# Extremely high    14
# Name: mountain_height_group, dtype: int64

# %% [markdown]
# ### Упражнение
#
# Загрузите в dataframe mountains содержимое Mountains.csv. Посчитайте следующие показателиЖ
#
#     1. Минимальную и максимальную высоту гор в наборе
#     2. В каком году было покорено наибольшее количество вершин (столбец First ascent),
#     3. Постройтераспределение ascent по годам

# %%
mountains = pd.read_csv('datasets/Homework/Mountains.csv', delimiter=',')
mountains.head()
# Out:
#    Rank                                  Mountain  Height (m)  Height (ft)  \
# 0     1  Mount Everest / Sagarmatha / Chomolungma        8848        29029
# 1     2                K2 / Qogir / Godwin Austen        8611        28251
# 2     3                             Kangchenjunga        8586        28169
# 3     4                                    Lhotse        8516        27940
# 4     5                                    Makalu        8485        27838
#
#    Prominence (m)                   Range              Coordinates  \
# 0            8848     Mahalangur Himalaya  27°59′17″N 86°55′31″E﻿
# 1            4017       Baltoro Karakoram  35°52′53″N 76°30′48″E﻿
# 2            3922  Kangchenjunga Himalaya  27°42′12″N 88°08′51″E﻿
# 3             610     Mahalangur Himalaya  27°57′42″N 86°55′59″E﻿
# 4            2386     Mahalangur Himalaya  27°53′23″N 87°05′20″E﻿
#
#   Parent mountain First ascent Ascents bef. 2004  Failed attempts bef. 2004
# 0             NaN         1953            >>145                       121.0
# 1   Mount Everest         1954                45                       44.0
# 2   Mount Everest         1955                38                       24.0
# 3   Mount Everest         1956                26                       26.0
# 4   Mount Everest         1955                45                       52.0

# %%
mountains.describe()
# Out:
#              Rank   Height (m)   Height (ft)  Prominence (m)  \
# count  118.000000   118.000000    118.000000      118.000000
# mean    59.500000  7578.042373  24862.364407     1671.567797
# std     34.207699   341.471211   1120.311905     1234.813419
# min      1.000000  7200.000000  23622.000000      217.000000
# 25%     30.250000  7316.500000  24004.000000      712.750000
# 50%     59.500000  7472.500000  24516.500000     1332.500000
# 75%     88.750000  7775.500000  25509.750000     2297.250000
# max    118.000000  8848.000000  29029.000000     8848.000000
#
#        Failed attempts bef. 2004
# count                 115.000000
# mean                    8.400000
# std                    15.782958
# min                     0.000000
# 25%                     1.000000
# 50%                     3.000000
# 75%                    11.000000
# max                   121.000000

# %%
print('Минимальная высота год в наборе', mountains['Height (m)'].min())

print('Максимальная высота год в наборе',mountains['Height (m)'].max())
# Out:
# Минимальная высота год в наборе 7200
# Максимальная высота год в наборе 8848

# %%
mountains['Height (m)'].value_counts()
# Out:
# 7492    2
# 7495    2
# 7462    2
# 7207    2
# 7350    2
#        ..
# 7711    1
# 7742    1
# 7751    1
# 7756    1
# 7200    1
# Name: Height (m), Length: 111, dtype: int64

# %%
mountains['First ascent'].value_counts().sort_index(sort_remaining=False)
# Out:
# 1930         1
# 1931         1
# 1932         1
# 1933         1
# 1934         1
# 1935         1
# 1936         1
# 1937         2
# 1938         1
# 1939         2
# 1950         3
# 1951         1
# 1953         2
# 1954         4
# 1955         3
# 1956         6
# 1957         2
# 1958         4
# 1959         2
# 1960         7
# 1961         4
# 1962         2
# 1964         4
# 1965         1
# 1968         1
# 1969         1
# 1970         4
# 1971         3
# 1973         1
# 1974         2
# 1975         5
# 1976         6
# 1977         1
# 1978         1
# 1979         3
# 1980         1
# 1981         3
# 1982         3
# 1984         2
# 1985         3
# 1986         4
# 1987         1
# 1988         1
# 1989         1
# 1992         1
# 1993         1
# 1994         4
# 1996         2
# 2002         1
# 2011         1
# unclimbed    4
# Name: First ascent, dtype: int64

# %%
# mountains.hist(column=['First ascent'])
mountains['First ascent'].hist(bins=100, figsize=(30, 5));

# %%
data[data['ageGroup'].isin(['Young', 'undef'])]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ageGroup
# 0        0         A/5 21171   7.2500   NaN        S    Young
# 1        0          PC 17599  71.2833   C85        C    Young
# 2        0  STON/O2. 3101282   7.9250   NaN        S    Young
# 3        0            113803  53.1000  C123        S    Young
# 4        0            373450   8.0500   NaN        S    Young
# ..     ...               ...      ...   ...      ...      ...
# 885      5            382652  29.1250   NaN        Q    Young
# 886      0            211536  13.0000   NaN        S    Young
# 887      0            112053  30.0000   B42        S    Young
# 889      0            111369  30.0000  C148        C    Young
# 890      0            370376   7.7500   NaN        Q    Young
#
# [564 rows x 13 columns]

# %% [markdown]
# ### Сохранение DataFrame

# %%
"""
    data.to_
    Help по функции
"""
# ?pd.DataFrame.to_csv

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html
# разделитель sep по умолчанию запятая
# na_rep - что ставим на место пустых ячеек
# columns - какие столбцы хотим записать
# index - включать ли номер строки

data.to_csv('datasets/train_modified.csv', sep=';', na_rep=0, columns=['Survived', 'ageGroup'], index=False)

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_json.html
# при сохранении в JSON может быть несколько вариантов группировки данных

# orient = index - строки имеют вид
# {"0":{"PassengerId":1,"Survived":0,"Pclass":3,"Name":"Braund, Mr. Owen Harris","Sex":"male","Age":22.0,"SibSp":1,"Parch":0,"Ticket":"A\/5 21171","Fare":7.25,"Cabin":null,"Embarked":"S","ageGroup":"Young"}

data.to_json('datasets/train_modified.json', orient='index')
# data.to_json('datasets/train_modified.json', orient='index', indent=4)  # Человекочитабельный формат

# %%
# Другие варианты

data.to_json('datasets/train_json_columns.json', orient='columns')
data.to_json('datasets/train_json_records.json', orient='records')

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_excel.html
# сохранение в Excel

data.to_excel('datasets/train_modified.xlsx', sheet_name='data')

# %% [markdown]
# ### Типовые действия с DF

# %%
data = pd.read_csv('datasets/train.csv')
data.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
