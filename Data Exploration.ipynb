# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('d:/Downloads/US_Regional_Sales_Data.xlsx', index_col=None)

# %%
df.head()
# Out:
#    OrderNumber Sales Channel WarehouseCode ProcuredDate  OrderDate   ShipDate  \
# 0  SO - 000101      In-Store  WARE-UHY1004   2017-12-31 2018-05-31 2018-06-14
# 1  SO - 000102        Online  WARE-NMK1003   2017-12-31 2018-05-31 2018-06-22
# 2  SO - 000103   Distributor  WARE-UHY1004   2017-12-31 2018-05-31 2018-06-21
# 3  SO - 000104     Wholesale  WARE-NMK1003   2017-12-31 2018-05-31 2018-06-02
# 4  SO - 000105   Distributor  WARE-NMK1003   2018-04-10 2018-05-31 2018-06-16
#
#   DeliveryDate CurrencyCode  _SalesTeamID  _CustomerID  _StoreID  _ProductID  \
# 0   2018-06-19          USD             6           15       259          12
# 1   2018-07-02          USD            14           20       196          27
# 2   2018-07-01          USD            21           16       213          16
# 3   2018-06-07          USD            28           48       107          23
# 4   2018-06-26          USD            22           49       111          26
#
# ...

# %%
df = df.drop('CurrencyCode', axis=1)
df.head()
# Out:
#    OrderNumber Sales Channel WarehouseCode ProcuredDate  OrderDate   ShipDate  \
# 0  SO - 000101      In-Store  WARE-UHY1004   2017-12-31 2018-05-31 2018-06-14
# 1  SO - 000102        Online  WARE-NMK1003   2017-12-31 2018-05-31 2018-06-22
# 2  SO - 000103   Distributor  WARE-UHY1004   2017-12-31 2018-05-31 2018-06-21
# 3  SO - 000104     Wholesale  WARE-NMK1003   2017-12-31 2018-05-31 2018-06-02
# 4  SO - 000105   Distributor  WARE-NMK1003   2018-04-10 2018-05-31 2018-06-16
#
#   DeliveryDate  _SalesTeamID  _CustomerID  _StoreID  _ProductID  \
# 0   2018-06-19             6           15       259          12
# 1   2018-07-02            14           20       196          27
# 2   2018-07-01            21           16       213          16
# 3   2018-06-07            28           48       107          23
# 4   2018-06-26            22           49       111          26
#
#    Order Quantity  Discount Applied  Unit Price  Unit Cost
# ...

# %% [markdown]
# 1. Выявляем лидера по каналам продаж
# 2. Выявляем самый продаваемый товар или топ 5-10
# 3. Выявляем самый дорогой и дешевый товар
# 4. Самые продаваемые товары за месяц
# 5. Максимальные и минимальные скидки на товары
# 6. Покупатель купивший наибольший и наименьший объем товара
# 7. Самая быстрая доставка, самая долгая доставка
# 8. Самый успешный отдел продаж за месяц
#
#
# Таблица содержит следующие столбцы:
# *
#  * 'OrderNumber',
#  * 'Sales Channel',
#  * 'WarehouseCode',
#  * 'ProcuredDate',
#  * 'OrderDate',
#  * 'ShipDate',
#  * 'DeliveryDate',
#  * '_SalesTeamID',
#  * '_CustomerID',
#  * '_StoreID',
#  * '_ProductID',
#  * 'Order Quantity',
#  * 'Discount Applied',
#  * 'Unit Price',
#  * 'Unit Cost'

# %%
df.isnull().count()
# Out:
# OrderNumber         7991
# Sales Channel       7991
# WarehouseCode       7991
# ProcuredDate        7991
# OrderDate           7991
# ShipDate            7991
# DeliveryDate        7991
# _SalesTeamID        7991
# _CustomerID         7991
# _StoreID            7991
# _ProductID          7991
# Order Quantity      7991
# Discount Applied    7991
# Unit Price          7991
# Unit Cost           7991
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7991 entries, 0 to 7990
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   OrderNumber       7991 non-null   object
#  1   Sales Channel     7991 non-null   object
#  2   WarehouseCode     7991 non-null   object
#  3   ProcuredDate      7991 non-null   datetime64[ns]
#  4   OrderDate         7991 non-null   datetime64[ns]
#  5   ShipDate          7991 non-null   datetime64[ns]
#  6   DeliveryDate      7991 non-null   datetime64[ns]
#  7   _SalesTeamID      7991 non-null   int64
#  8   _CustomerID       7991 non-null   int64
#  9   _StoreID          7991 non-null   int64
#  10  _ProductID        7991 non-null   int64
#  11  Order Quantity    7991 non-null   int64
#  12  Discount Applied  7991 non-null   float64
#  13  Unit Price        7991 non-null   float64
#  14  Unit Cost         7991 non-null   float64
# ...

# %%
df['ShipDate'].unique()
# Out:
# array(['2018-06-14T00:00:00.000000000', '2018-06-22T00:00:00.000000000',
#        '2018-06-21T00:00:00.000000000', '2018-06-02T00:00:00.000000000',
#        '2018-06-16T00:00:00.000000000', '2018-06-08T00:00:00.000000000',
#        '2018-06-26T00:00:00.000000000', '2018-06-29T00:00:00.000000000',
#        '2018-06-15T00:00:00.000000000', '2018-06-07T00:00:00.000000000',
#        '2018-06-24T00:00:00.000000000', '2018-06-19T00:00:00.000000000',
#        '2018-06-06T00:00:00.000000000', '2018-06-11T00:00:00.000000000',
#        '2018-06-18T00:00:00.000000000', '2018-06-10T00:00:00.000000000',
#        '2018-06-20T00:00:00.000000000', '2018-06-27T00:00:00.000000000',
#        '2018-06-05T00:00:00.000000000', '2018-06-30T00:00:00.000000000',
#        '2018-06-28T00:00:00.000000000', '2018-06-13T00:00:00.000000000',
#        '2018-06-09T00:00:00.000000000', '2018-06-12T00:00:00.000000000',
#        '2018-06-25T00:00:00.000000000', '2018-07-03T00:00:00.000000000',
# ...
